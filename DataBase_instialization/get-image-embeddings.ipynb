# %%
import os
base_directory = "../afhq/train/cat"
all_image_urls = os.listdir(base_directory)
all_image_urls[:10]
# Out:
# ['flickr_cat_000002.jpg',
#  'flickr_cat_000003.jpg',
#  'flickr_cat_000004.jpg',
#  'flickr_cat_000005.jpg',
#  'flickr_cat_000006.jpg',
#  'flickr_cat_000007.jpg',
#  'flickr_cat_000009.jpg',
#  'flickr_cat_000010.jpg',
#  'flickr_cat_000012.jpg',
#  'flickr_cat_000013.jpg']

# %%
# 2. There's a lot of images (5k+) to fit in memory all at once, so let's just grab the first 100 for now
# Make it less if you have low memory
sample_image_urls = all_image_urls[:100]
sample_image_urls = list(map(lambda item: f"{base_directory}/{item}", sample_image_urls))
sample_image_urls
# Out:
# ['../afhq/train/cat/flickr_cat_000002.jpg',
#  '../afhq/train/cat/flickr_cat_000003.jpg',
#  '../afhq/train/cat/flickr_cat_000004.jpg',
#  '../afhq/train/cat/flickr_cat_000005.jpg',
#  '../afhq/train/cat/flickr_cat_000006.jpg',
#  '../afhq/train/cat/flickr_cat_000007.jpg',
#  '../afhq/train/cat/flickr_cat_000009.jpg',
#  '../afhq/train/cat/flickr_cat_000010.jpg',
#  '../afhq/train/cat/flickr_cat_000012.jpg',
#  '../afhq/train/cat/flickr_cat_000013.jpg',
#  '../afhq/train/cat/flickr_cat_000014.jpg',
#  '../afhq/train/cat/flickr_cat_000015.jpg',
#  '../afhq/train/cat/flickr_cat_000017.jpg',
#  '../afhq/train/cat/flickr_cat_000018.jpg',
#  '../afhq/train/cat/flickr_cat_000019.jpg',
#  '../afhq/train/cat/flickr_cat_000020.jpg',
#  '../afhq/train/cat/flickr_cat_000021.jpg',
#  '../afhq/train/cat/flickr_cat_000022.jpg',
#  '../afhq/train/cat/flickr_cat_000023.jpg',
#  '../afhq/train/cat/flickr_cat_000024.jpg',
#  '../afhq/train/cat/flickr_cat_000025.jpg',
#  '../afhq/train/cat/flickr_cat_000026.jpg',
#  '../afhq/train/cat/flickr_cat_000027.jpg',
#  '../afhq/train/cat/flickr_cat_000028.jpg',
#  '../afhq/train/cat/flickr_cat_000029.jpg',
#  '../afhq/train/cat/flickr_cat_000030.jpg',
#  '../afhq/train/cat/flickr_cat_000031.jpg',
#  '../afhq/train/cat/flickr_cat_000032.jpg',
#  '../afhq/train/cat/flickr_cat_000033.jpg',
#  '../afhq/train/cat/flickr_cat_000034.jpg',
#  '../afhq/train/cat/flickr_cat_000035.jpg',
#  '../afhq/train/cat/flickr_cat_000036.jpg',
#  '../afhq/train/cat/flickr_cat_000037.jpg',
#  '../afhq/train/cat/flickr_cat_000038.jpg',
#  '../afhq/train/cat/flickr_cat_000039.jpg',
#  '../afhq/train/cat/flickr_cat_000040.jpg',
#  '../afhq/train/cat/flickr_cat_000041.jpg',
#  '../afhq/train/cat/flickr_cat_000042.jpg',
#  '../afhq/train/cat/flickr_cat_000043.jpg',
#  '../afhq/train/cat/flickr_cat_000044.jpg',
#  '../afhq/train/cat/flickr_cat_000045.jpg',
#  '../afhq/train/cat/flickr_cat_000046.jpg',
#  '../afhq/train/cat/flickr_cat_000047.jpg',
#  '../afhq/train/cat/flickr_cat_000048.jpg',
#  '../afhq/train/cat/flickr_cat_000049.jpg',
#  '../afhq/train/cat/flickr_cat_000050.jpg',
#  '../afhq/train/cat/flickr_cat_000051.jpg',
#  '../afhq/train/cat/flickr_cat_000052.jpg',
#  '../afhq/train/cat/flickr_cat_000053.jpg',
#  '../afhq/train/cat/flickr_cat_000054.jpg',
#  '../afhq/train/cat/flickr_cat_000055.jpg',
#  '../afhq/train/cat/flickr_cat_000057.jpg',
#  '../afhq/train/cat/flickr_cat_000058.jpg',
#  '../afhq/train/cat/flickr_cat_000059.jpg',
#  '../afhq/train/cat/flickr_cat_000060.jpg',
#  '../afhq/train/cat/flickr_cat_000061.jpg',
#  '../afhq/train/cat/flickr_cat_000062.jpg',
#  '../afhq/train/cat/flickr_cat_000063.jpg',
#  '../afhq/train/cat/flickr_cat_000064.jpg',
#  '../afhq/train/cat/flickr_cat_000065.jpg',
#  '../afhq/train/cat/flickr_cat_000066.jpg',
#  '../afhq/train/cat/flickr_cat_000067.jpg',
#  '../afhq/train/cat/flickr_cat_000068.jpg',
#  '../afhq/train/cat/flickr_cat_000069.jpg',
#  '../afhq/train/cat/flickr_cat_000070.jpg',
#  '../afhq/train/cat/flickr_cat_000071.jpg',
#  '../afhq/train/cat/flickr_cat_000072.jpg',
#  '../afhq/train/cat/flickr_cat_000073.jpg',
#  '../afhq/train/cat/flickr_cat_000074.jpg',
#  '../afhq/train/cat/flickr_cat_000075.jpg',
#  '../afhq/train/cat/flickr_cat_000077.jpg',
#  '../afhq/train/cat/flickr_cat_000078.jpg',
#  '../afhq/train/cat/flickr_cat_000079.jpg',
#  '../afhq/train/cat/flickr_cat_000081.jpg',
#  '../afhq/train/cat/flickr_cat_000082.jpg',
#  '../afhq/train/cat/flickr_cat_000083.jpg',
#  '../afhq/train/cat/flickr_cat_000084.jpg',
#  '../afhq/train/cat/flickr_cat_000085.jpg',
#  '../afhq/train/cat/flickr_cat_000086.jpg',
#  '../afhq/train/cat/flickr_cat_000087.jpg',
#  '../afhq/train/cat/flickr_cat_000088.jpg',
#  '../afhq/train/cat/flickr_cat_000089.jpg',
#  '../afhq/train/cat/flickr_cat_000090.jpg',
#  '../afhq/train/cat/flickr_cat_000091.jpg',
#  '../afhq/train/cat/flickr_cat_000092.jpg',
#  '../afhq/train/cat/flickr_cat_000093.jpg',
#  '../afhq/train/cat/flickr_cat_000094.jpg',
#  '../afhq/train/cat/flickr_cat_000095.jpg',
#  '../afhq/train/cat/flickr_cat_000097.jpg',
#  '../afhq/train/cat/flickr_cat_000098.jpg',
#  '../afhq/train/cat/flickr_cat_000099.jpg',
#  '../afhq/train/cat/flickr_cat_000100.jpg',
#  '../afhq/train/cat/flickr_cat_000101.jpg',
#  '../afhq/train/cat/flickr_cat_000102.jpg',
#  '../afhq/train/cat/flickr_cat_000103.jpg',
#  '../afhq/train/cat/flickr_cat_000104.jpg',
#  '../afhq/train/cat/flickr_cat_000105.jpg',
#  '../afhq/train/cat/flickr_cat_000106.jpg',
#  '../afhq/train/cat/flickr_cat_000107.jpg',
#  '../afhq/train/cat/flickr_cat_000109.jpg']

# %%
# 3. Create a dataframe to store the image's metadata
from pandas import DataFrame
from PIL import Image
payloads = DataFrame.from_records({"image_url": sample_image_urls})
payloads ["type"] = "cat"
payloads ["gov"] = "Egypt-Dakahlia-Mansoura"
payloads ["location"] = "Mashaya near MU Baron Gate"
payloads ["petID"] = "4:17:2024:10:14:43:1354"
payloads ["note"] = "phone number : 01001318401631518"
payloads ["missing"] = 1
payloads
# Out:
#                                   image_url type                      gov  \
# 0   ../afhq/train/cat/flickr_cat_000002.jpg  cat  Egypt-Dakahlia-Mansoura
# 1   ../afhq/train/cat/flickr_cat_000003.jpg  cat  Egypt-Dakahlia-Mansoura
# 2   ../afhq/train/cat/flickr_cat_000004.jpg  cat  Egypt-Dakahlia-Mansoura
# 3   ../afhq/train/cat/flickr_cat_000005.jpg  cat  Egypt-Dakahlia-Mansoura
# 4   ../afhq/train/cat/flickr_cat_000006.jpg  cat  Egypt-Dakahlia-Mansoura
# ..                                      ...  ...                      ...
# 95  ../afhq/train/cat/flickr_cat_000104.jpg  cat  Egypt-Dakahlia-Mansoura
# 96  ../afhq/train/cat/flickr_cat_000105.jpg  cat  Egypt-Dakahlia-Mansoura
# 97  ../afhq/train/cat/flickr_cat_000106.jpg  cat  Egypt-Dakahlia-Mansoura
# 98  ../afhq/train/cat/flickr_cat_000107.jpg  cat  Egypt-Dakahlia-Mansoura
# 99  ../afhq/train/cat/flickr_cat_000109.jpg  cat  Egypt-Dakahlia-Mansoura
#
#                       location                    petID  \
# 0   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 1   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 2   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 3   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 4   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# ..                         ...                      ...
# 95  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 96  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 97  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 98  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 99  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
#
#                                 note  missing
# 0   phone number : 01001318401631518        1
# 1   phone number : 01001318401631518        1
# 2   phone number : 01001318401631518        1
# 3   phone number : 01001318401631518        1
# 4   phone number : 01001318401631518        1
# ..                               ...      ...
# 95  phone number : 01001318401631518        1
# 96  phone number : 01001318401631518        1
# 97  phone number : 01001318401631518        1
# 98  phone number : 01001318401631518        1
# 99  phone number : 01001318401631518        1
#
# [100 rows x 7 columns]

# %%
Image.open(payloads['image_url'][1])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
Image.open(payloads['image_url'][0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
# 4. Create PIL images from each of the local URLs that we created in the last step
images = list(map(lambda el: Image.open(el), payloads["image_url"]))
images
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>]

# %%
# 5. Create base64 string representations to store alongside
# the metadata. This will allow us to preview the images on our app
from io import BytesIO
import math
import base64

target_width = 256

def resize_image(image_url):
    pil_image = Image.open(image_url)
    image_aspect_ratio= pil_image.width / pil_image.height
    resized_pil_image = pil_image.resize([target_width, math.floor(target_width * image_aspect_ratio)])
    return resized_pil_image


def convert_image_to_base64(pil_image):
    image_data = BytesIO()
    pil_image.save(image_data, format="JPEG")
    base64_string = base64.b64encode(image_data.getvalue()).decode("utf-8")
    return base64_string

resized_images = list(map(lambda el: resize_image(el), sample_image_urls))
base64_strings = list(map(lambda el: convert_image_to_base64(el), resized_images))
payloads["base64"] = base64_strings
payloads
# Out:
#                                   image_url type                      gov  \
# 0   ../afhq/train/cat/flickr_cat_000002.jpg  cat  Egypt-Dakahlia-Mansoura
# 1   ../afhq/train/cat/flickr_cat_000003.jpg  cat  Egypt-Dakahlia-Mansoura
# 2   ../afhq/train/cat/flickr_cat_000004.jpg  cat  Egypt-Dakahlia-Mansoura
# 3   ../afhq/train/cat/flickr_cat_000005.jpg  cat  Egypt-Dakahlia-Mansoura
# 4   ../afhq/train/cat/flickr_cat_000006.jpg  cat  Egypt-Dakahlia-Mansoura
# ..                                      ...  ...                      ...
# 95  ../afhq/train/cat/flickr_cat_000104.jpg  cat  Egypt-Dakahlia-Mansoura
# 96  ../afhq/train/cat/flickr_cat_000105.jpg  cat  Egypt-Dakahlia-Mansoura
# 97  ../afhq/train/cat/flickr_cat_000106.jpg  cat  Egypt-Dakahlia-Mansoura
# 98  ../afhq/train/cat/flickr_cat_000107.jpg  cat  Egypt-Dakahlia-Mansoura
# 99  ../afhq/train/cat/flickr_cat_000109.jpg  cat  Egypt-Dakahlia-Mansoura
#
#                       location                    petID  \
# 0   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 1   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 2   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 3   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 4   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# ..                         ...                      ...
# 95  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 96  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 97  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 98  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 99  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
#
#                                 note  missing  \
# 0   phone number : 01001318401631518        1
# 1   phone number : 01001318401631518        1
# 2   phone number : 01001318401631518        1
# 3   phone number : 01001318401631518        1
# 4   phone number : 01001318401631518        1
# ..                               ...      ...
# 95  phone number : 01001318401631518        1
# 96  phone number : 01001318401631518        1
# 97  phone number : 01001318401631518        1
# 98  phone number : 01001318401631518        1
# 99  phone number : 01001318401631518        1
#
#                                                base64
# 0   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# ..                                                ...
# 95  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 96  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 97  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 98  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 99  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
# [100 rows x 8 columns]

# %%
base64_strings
# Out:
# ['...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...']

# %% [markdown]
# - pip install protobuf==3.20.0

# %%
# 6. Import the model and the tokenizer, then run all of the images through it to create the embeddings
import torch
from transformers import AutoImageProcessor, ResNetForImageClassification
from tqdm import tqdm
# Move model to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
processor = AutoImageProcessor.from_pretrained("microsoft/resnet-50")
model = ResNetForImageClassification.from_pretrained("microsoft/resnet-50").to(device)

# Process images in batches
batch_size = 16
embeddings_list = []
num_images = len(images)
batch_range = range(0, num_images, batch_size)

# Initialize tqdm with the total number of batches
for i in tqdm(batch_range, desc="Processing Batches", total=len(batch_range)):
    batch_images = images[i:i+batch_size]
    batch_inputs = processor(batch_images, return_tensors="pt").to(device)
    batch_outputs = model(**batch_inputs)
    batch_embeddings = batch_outputs.logits
    embeddings_list.append(batch_embeddings)

# Concatenate or aggregate embeddings from different batches
# Concatenate tensors along dimension 0
embeddings = torch.cat(embeddings_list, dim=0)
# Print embeddings
print(embeddings)

# %%
embeddings[1]
# Out:
# tensor([-10.3439, -10.4525,  -9.0364, -11.1825, -12.0630, -10.0207, -10.1732,
#          -7.9250,  -6.4620,  -8.3850, -10.0058,  -8.3647,  -9.3319,  -8.6133,
#          -9.1372,  -8.5522,  -9.5092,  -9.5246,  -9.5207, -11.1756,  -9.8854,
#          -9.7788,  -7.4301,  -9.2707,  -9.4861,  -9.1077,  -8.8324,  -7.5389,
#          -9.6024,  -8.4608,  -8.6464,  -8.2779,  -9.3688,  -8.8651,  -8.0599,
#          -8.8187,  -7.9914, -10.0234,  -9.6643,  -9.7251,  -9.2356,  -8.4963,
#          -9.4238,  -9.1232,  -8.7041,  -9.9507,  -8.9388,  -9.4199,  -9.2760,
#         -10.2410, -10.8338,  -9.5827,  -8.9586, -10.1013,  -8.7467,  -9.1306,
#          -9.8951, -10.7653,  -9.5297, -11.2822, -10.5840,  -9.4721, -10.0280,
#          -9.3074,  -8.7073,  -8.3011,  -9.1620,  -9.9770,  -8.7269,  -9.0803,
#          -8.2754, -10.0671,  -8.0232,  -7.3115, -10.2988,  -8.4908, -10.7558,
#         -10.0635, -10.1193, -10.3896, -10.2831,  -9.3934, -10.3216, -11.7680,
#          -9.8388,  -9.7824,  -9.2241, -10.6966,  -9.8157, -10.5710, -11.3749,
#          -8.8313,  -9.0973, -10.3953,  -9.8040, -11.0093, -10.2539, -11.5899,
#         -10.7934, -10.7825,  -9.4442, -10.2297,  -7.2062,  -8.6609],
#        device='cuda:0', grad_fn=<SelectBackward0>)

# %%
#embeddings_cpu = embeddings.cpu()

# %%
# 7. Store the length of the embedding. We'll need
# this later
embedding_length = len(embeddings[0])
print('embedding_length:',embedding_length)
print('embedding_shape:',embeddings.shape)
# Out:
# embedding_length: 1000
# embedding_shape: torch.Size([100, 1000])

# %%
# 8.5 Jump over to Qdrant and create a new Cloud account
# You'll need a Cluster URL and an API key to continue.

# %%
# URL and API already added to env
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# 9. Intialize the Qdrant client using the environment
#variables that were just loaded
from qdrant_client import QdrantClient
import os

qclient = QdrantClient(
    url = os.getenv('QDRANT_DB_URL'),
    api_key = os.getenv('QDRANT_API_KEY'),
)
qclient

# %%
collection_name = "Egypt-Dakahlia-Mansoura"

# %%
'''
# 10. Create (or-create) a collection called "animal_images".
# This is the collection that our vectors and metadata will be stored in.
from qdrant_client.models import VectorParams, Distance

collection = qclient.recreate_collection(
    collection_name= collection_name,
    vectors_config= VectorParams(
        size = embedding_length,
        distance = Distance.COSINE
    )
)
collection
'''
# Out:
# True

# %%
payloads
# Out:
#                                   image_url type                      gov  \
# 0   ../afhq/train/cat/flickr_cat_000002.jpg  cat  Egypt-Dakahlia-Mansoura
# 1   ../afhq/train/cat/flickr_cat_000003.jpg  cat  Egypt-Dakahlia-Mansoura
# 2   ../afhq/train/cat/flickr_cat_000004.jpg  cat  Egypt-Dakahlia-Mansoura
# 3   ../afhq/train/cat/flickr_cat_000005.jpg  cat  Egypt-Dakahlia-Mansoura
# 4   ../afhq/train/cat/flickr_cat_000006.jpg  cat  Egypt-Dakahlia-Mansoura
# ..                                      ...  ...                      ...
# 95  ../afhq/train/cat/flickr_cat_000104.jpg  cat  Egypt-Dakahlia-Mansoura
# 96  ../afhq/train/cat/flickr_cat_000105.jpg  cat  Egypt-Dakahlia-Mansoura
# 97  ../afhq/train/cat/flickr_cat_000106.jpg  cat  Egypt-Dakahlia-Mansoura
# 98  ../afhq/train/cat/flickr_cat_000107.jpg  cat  Egypt-Dakahlia-Mansoura
# 99  ../afhq/train/cat/flickr_cat_000109.jpg  cat  Egypt-Dakahlia-Mansoura
#
#                       location                    petID  \
# 0   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 1   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 2   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 3   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 4   Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# ..                         ...                      ...
# 95  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 96  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 97  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 98  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
# 99  Mashaya near MU Baron Gate  4:17:2024:10:14:43:1354
#
#                                 note  missing  \
# 0   phone number : 01001318401631518        1
# 1   phone number : 01001318401631518        1
# 2   phone number : 01001318401631518        1
# 3   phone number : 01001318401631518        1
# 4   phone number : 01001318401631518        1
# ..                               ...      ...
# 95  phone number : 01001318401631518        1
# 96  phone number : 01001318401631518        1
# 97  phone number : 01001318401631518        1
# 98  phone number : 01001318401631518        1
# 99  phone number : 01001318401631518        1
#
#                                                base64
# 0   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4   /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# ..                                                ...
# 95  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 96  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 97  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 98  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 99  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
# [100 rows x 8 columns]

# %%
# 11. The metadata must be uploaded as an array of objects, so
# convert the dataframe to an array of objects before continuing
payload_dicts = payloads.to_dict(
    orient="records"
)

# %%
payload_dicts[0]
# Out:
# {'image_url': '../afhq/train/cat/flickr_cat_000002.jpg',
#  'type': 'cat',
#  'gov': 'Egypt-Dakahlia-Mansoura',
#  'location': 'Mashaya near MU Baron Gate',
#  'petID': '4:17:2024:10:14:43:1354',
#  'note': 'phone number : 01001318401631518',
#  'missing': 1,
#  'base64': '...'}

# %%
# 12. Create the record.This is the payload (metadata) and the 
# vectore (embedding) side-by-side. Because we have two arrays
# of data that share the same index, we can just enumerate over
# one of those arrays and use the index to create the record.
from qdrant_client import models

last_idx = qclient.count(
            collection_name=collection_name,
        ).count
records = [
    models.Record(
        id= last_idx + idx,
        payload = payload_dicts[idx],
        vector = embeddings[idx]
    )
    for idx,_ in enumerate(payload_dicts)
]

# %%
len(records)
# Out:
# 100

# %%
records[0]
# Out:
# Record(id=0, payload={'image_url': '../afhq/train/cat/flickr_cat_000002.jpg', 'type': 'cat', 'gov': 'Egypt-Dakahlia-Mansoura', 'location': 'Mashaya near MU Baron Gate', 'petID': '4:17:2024:10:14:43:1354', 'note': 'phone number : 01001318401631518', 'missing': 1, 'base64': '...'}, vector=[-9.638439178466797, -9.42475700378418, -10.244549751281738, -11.732656478881836, -10.911715507507324, -9.933865547180176, -10.137188911437988, -9.994892120361328, -9.571104049682617, -10.493754386901855, -9.253887176513672, -10.03575325012207, -10.017465591430664, -10.839620590209961, -10.054645538330078, -8.88115406036377, -10.287625312805176, -10.218717575073242, -9.724654197692871, -9.78139877319336, -9.552096366882324, -9.833617210388184, -10.840015411376953, -9.276630401611328, -10.34727668762207, -11.037552833557129, -9.053232192993164, -9.77182388305664, -10.652463912963867, -9.435020446777344, -10.129938